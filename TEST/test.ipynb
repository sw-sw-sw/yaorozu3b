# %%
import numpy as np 

positions =  np.zeros((100, 2), dtype=np.float32)
positions
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 import numpy as np
# ----> 3 positions =  np.arange((100, 2), dtype=np.float32)
#       4 positions
#
# TypeError: arange: scalar arguments expected instead of a tuple.

# %%
for i , positions in enumerate(positions):
    self.creatures[i].update(pygame.Vector2(new_pos[0], new_pos[1]))
# Out:
# [1, 2, 3, 4, 5]
