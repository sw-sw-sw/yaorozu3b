# %%
import numpy as np 

positions = np.zeros((100, 4), dtype=np.float32)
positions.shape[0]
num = 50
positions[:num,3] = np.arange(0,num)
np.sum(positions[:,3] != 0)
# Out:
# 49

# %%
# Out:
# [1, 2, 3, 4, 5]
